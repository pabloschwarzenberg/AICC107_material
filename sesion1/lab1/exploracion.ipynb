# %%
import pandas as pd
data=pd.read_csv("dataset.csv",delimiter=";")
data=data[["estado","e0","e1","e2"]]

# %%
data.astype("object").groupby("estado").describe().T
# Out:
# estado       A   R
# e0 count   418  49
#    unique    2   2
#    top       1   0
#    freq    335  39
# e1 count   418  49
#    unique    2   2
#    top       1   0
#    freq    267  46
# e2 count   418  49
#    unique    2   2
#    top       0   0
#    freq    402  48

# %%
pd.crosstab(data["estado"],data["e0"],normalize="index").plot.bar()
# Out:
# <Axes: xlabel='estado'>

# %%
pd.crosstab(data["estado"],data["e1"],normalize="index").plot.bar()
# Out:
# <Axes: xlabel='estado'>

# %%
pd.crosstab(data["estado"],data["e2"],normalize="index").plot.bar()
# Out:
# <Axes: xlabel='estado'>
